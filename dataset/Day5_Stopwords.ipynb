# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(list(stop_words)[:5])
# Out:
# ['ourselves', "they'll", 'isn', "she's", 'which']

# %%
import string
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return " ".join(words)

sample = "This agreement is made between two parties"
print(clean_text(sample))
# Out:
# agreement made two parties

# %%
import pandas as pd

data = pd.read_csv("legal_dataset.csv")

data["cleaned_text"] = data["text"].apply(clean_text)

print(data.head())
# Out:
#                                             text  label  \
# 0      THIS agreement is made btwn two parties!!      1
# 1  the CONTRACT shall remain valid for 1 year...      1
# 2     party-A agrees to all terms & conditions!!      1
# 3                 this doc is legally binding!!!      1
# 4     the affidavit was signed b4 the authority.      1
#
#                          cleaned_text
# 0     agreement made btwn two parties
# 1  contract shall remain valid 1 year
# 2      partya agrees terms conditions
# 3                 doc legally binding
# 4       affidavit signed b4 authority

# %%
text = "legal agreement signed today"
words = text.split()
print(words)
# Out:
# ['legal', 'agreement', 'signed', 'today']
