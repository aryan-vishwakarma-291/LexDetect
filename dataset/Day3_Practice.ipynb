# %%
LegalDocDetector/dataset/legal_dataset.csv

# %%
import pandas as pd
data = pd.read_csv("legal_dataset.csv")
print(data)
# Out:
#                                                  text  label
# 0         this agreement is made between two parties.      1
# 1       the contract shall remain valid for one year.      1
# 2   the party agrees to follow all terms and condi...      1
# 3                   this document is legally binding.      1
# 4       the affidavit is signed before the authority.      1
# 5                   the court issued the final order.      1
# 6               the defendant submitted the evidence.      1
# 7              the plaintiff filed a legal complaint.      1
# 8          the agreement may be terminated by notice.      1
# 9          all disputes will be settled by the court.      1
# 10       the party accepts full legal responsibility.      1
# 11  this clause explains the liability of both par...      1
# 12       the document must be signed by both parties.      1
# 13         the court has jurisdiction over this case.      1
# ...
