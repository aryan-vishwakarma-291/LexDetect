# %%
text = "This AGREEMENT is Made!!!"
clean_text = text.lower()
print(clean_text)
# Out:
# this agreement is made!!!

# %%
import string

text = "This agreement is made!!!"
clean_text = text.translate(str.maketrans('', '', string.punctuation))
print(clean_text)
# Out:
# This agreement is made

# %%
import string

def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

sample = "This AGREEMENT is Made!!!"
print(clean_text(sample))
# Out:
# this agreement is made

# %%
import pandas as pd
import string

data = pd.read_csv("legal_dataset.csv")

def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

data["cleaned_text"] = data["text"].apply(clean_text

print(data.head())
# Out:
#                                             text  label  \
# 0      THIS agreement is made btwn two parties!!      1
# 1  the CONTRACT shall remain valid for 1 year...      1
# 2     party-A agrees to all terms & conditions!!      1
# 3                 this doc is legally binding!!!      1
# 4     the affidavit was signed b4 the authority.      1
#
#                                  cleaned_text
# 0     this agreement is made btwn two parties
# 1  the contract shall remain valid for 1 year
# 2      partya agrees to all terms  conditions
# 3                 this doc is legally binding
# 4   the affidavit was signed b4 the authority
